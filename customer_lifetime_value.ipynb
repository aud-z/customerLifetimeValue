# %% [markdown]
# # Customer Lifetime Value Analysis
# ### Data Science for Product Managers HW1
# ### Audrey Zhang

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import math
from dateutil.relativedelta import *

# %%
df = pd.read_csv('HW1 clv_transactions.csv')

# %% [markdown]
# ##### explore dataset

# %%
# check out dataframe 
df.head()
# Out:
#    TransactionID TransactionDate  CustomerID  Amount
# 0              1        9/4/2012           1   20.26
# 1              2       5/15/2012           2   10.87
# 2              3       5/23/2014           2    2.21
# 3              4      10/24/2014           2   10.48
# 4              5      10/13/2012           2    3.94

# %% [markdown]
# There are no null values in the dataset:

# %%
df.info()
# there are no null (missing) values
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4186 entries, 0 to 4185
# Data columns (total 4 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   TransactionID    4186 non-null   int64
#  1   TransactionDate  4186 non-null   object
#  2   CustomerID       4186 non-null   int64
#  3   Amount           4186 non-null   float64
# dtypes: float64(1), int64(2), object(1)
# memory usage: 130.9+ KB

# %%
# cast date values to datetime format
df['TransactionDate'] = pd.to_datetime(df['TransactionDate'])

# %% [markdown]
# Next, check out the date ranges. The earliest transaction is 2010/01/04 and the latest is 2015/12/31.

# %%
df['TransactionDate'].min()
# Out:
# Timestamp('2010-01-04 00:00:00')

# %%
df['TransactionDate'].max()
# Out:
# Timestamp('2015-12-31 00:00:00')

# %% [markdown]
# There are 1000 unique customers in this dataset.

# %%
len(df['CustomerID'].unique())
# Out:
# 1000

# %% [markdown]
# Next, take a look at the data distribution of the 'amount' field. The minimum value is -1 and the maximum is 2,033. The standard deviation is 38.72. The variance is 1499.54.

# %%
df['Amount'].describe()
# Out:
# count    4186.000000
# mean        9.028082
# std        38.723909
# min        -1.000000
# 25%         3.310000
# 50%         6.885000
# 75%        11.690000
# max      2033.000000
# Name: Amount, dtype: float64

# %%
df['Amount'].var()
# Out:
# 1499.5411107517461

# %% [markdown]
# It is unclear why there are observations with -1 in the Amount column. This warrants further investigation.

# %%
df[df['Amount']<0]
# Out:
#       TransactionID TransactionDate  CustomerID  Amount
# 49               50      2012-05-12          13    -1.0
# 3326           3327      2014-01-16         811    -1.0

# %% [markdown]
# It looks like there are only two such transactions, which may be outliers. They may warrant being removed from the analysis.

# %%
import plotly.express as px
fig = px.box(df, y="Amount")
fig.show()
# Out:
# <div>                            <div id="dc89844d-9c9b-4b00-9677-3e96920fb436" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("dc89844d-9c9b-4b00-9677-3e96920fb436")) {                    Plotly.newPlot(                        "dc89844d-9c9b-4b00-9677-3e96920fb436",                        [{"alignmentgroup": "True", "hovertemplate": "Amount=%{y}<extra></extra>", "legendgroup": "", "marker": {"color": "#636efa"}, "name": "", "notched": false, "offsetgroup": "", "orientation": "v", "showlegend": false, "type": "box", "x0": " ", "xaxis": "x", "y": [20.26, 10.87, 2.21, 10.48, 3.94, 12.37, 1.59, 2.75, 3.51, 21.58, 15.43, 5.45, 1.67, 2.23, 9.92, 6.16, 0.54, 14.54, 6.9, 2.56, 17.02, 8.18, 9.44, 1003.0, 6.21, 2.35, 0.52, 6.58, 0.74, 11.87, 15.5, 11.46, 7.99, 2.97, 12.37, 5.99, 0.95, 8.81, 10.94, 20.21, 12.97, 4.78, 2.4, 13.91, 17.6, 0.5, 10.21, 5.1, 16.46, -1.0, 9.67, 7.08, 14.45, 10.63, 37.27, 20.44, 7.84, 2.05, 0.36, 3.43, 4.78, 1.29, 28.72, 0.86, 9.22, 6.63, 1.85, 0.6, 2.69, 17.84, 6.0, 2.51, 8.34, 11.32, 10.8, 18.33, 6.01, 11.01, 15.04, 0.21, 18.05, 4.53, 6.24, 8.38, 3.67, 19.6, 4.55, 1.5, 0.49, 14.07, 10.33, 5.81, 15.92, 10.72, 9.36, 5.03, 2.26, 10.95, 0.19, 4.43, 2.47, 8.23, 7.73, 5.62, 6.98, 5.68, 13.45, 5.35, 14.47, 3.45, 3.9, 1.18, 2.81, 4.68, 7.66, 9.32, 0.96, 1.81, 9.93, 3.27, 0.52, 5.14, 3.95, 9.81, 10.26, 10.91, 12.28, 21.13, 2.78, 13.44, 1.77, 2.65, 12.03, 4.92, 1.91, 13.82, 25.6, 2.47, 5.02, 2.23, 12.3, 12.82, 2.74, 0.25, 9.72, 4.3, 2.45, 4.78, 11.75, 0.94, 8.21, 2.99, 0.04, 9.51, 12.7, 11.29, 4.83, 2.3, 5.52, 6.0, 7.18, 12.39, 17.82, 0.75, 3.47, 29.12, 8.49, 3.49, 11.57, 3.27, 9.8, 14.94, 4.97, 0.73, 3.69, 11.4, 22.53, 19.95, 11.39, 1.55, 11.12, 10.66, 2.61, 5.97, 24.05, 8.91, 9.77, 1.43, 5.9, 8.11, 8.19, 4.57, 12.2, 13.24, 8.23, 12.61, 5.28, 1.08, 10.12, 22.84, 10.19, 5.4, 10.49, 7.83, 7.85, 1.57, 0.96, 8.83, 1.92, 0.25, 13.85, 1027.0, 11.6, 15.1, 5.49, 0.9, 6.69, 7.21, 8.09, 11.61, 10.48, 1.64, 6.58, 10.76, 5.55, 9.96, 3.54, 3.35, 10.64, 2.64, 6.97, 5.81, 3.89, 8.67, 6.93, 3.54, 9.49, 9.6, 13.92, 12.23, 3.45, 5.86, 14.74, 13.46, 12.79, 13.33, 4.43, 7.21, 4.26, 7.49, 4.95, 3.47, 0.39, 1.35, 0.78, 1.25, 11.74, 14.2, 4.82, 0.45, 0.54, 3.4, 23.85, 38.29, 9.18, 4.4, 10.8, 0.37, 7.33, 23.95, 6.29, 11.83, 2.19, 11.66, 13.09, 2.43, 7.57, 0.58, 3.44, 17.72, 2.65, 7.73, 7.28, 4.49, 5.71, 4.48, 4.58, 8.43, 7.38, 9.06, 6.85, 14.21, 10.67, 9.45, 0.87, 1.22, 18.42, 14.44, 0.32, 9.08, 0.76, 20.58, 7.6, 9.41, 3.09, 11.88, 3.83, 5.01, 4.63, 11.55, 10.93, 1.5, 9.3, 1.82, 15.37, 6.61, 2.15, 2.26, 3.02, 2.18, 4.59, 3.64, 8.31, 10.43, 0.71, 2.79, 14.85, 14.05, 3.65, 3.46, 24.27, 17.48, 1.78, 3.95, 1.78, 8.99, 0.25, 21.01, 3.17, 14.72, 3.72, 2.63, 2.86, 2.84, 7.68, 3.59, 4.58, 1.19, 13.06, 3.13, 20.02, 7.78, 4.62, 0.2, 4.57, 13.4, 18.19, 2.64, 4.78, 11.29, 6.41, 5.53, 4.69, 17.4, 4.99, 12.51, 13.34, 7.28, 10.16, 17.93, 8.84, 13.46, 13.08, 10.89, 29.5, 7.67, 12.06, 20.04, 1.06, 0.59, 3.53, 6.33, 10.5, 3.74, 17.78, 16.45, 0.13, 8.1, 0.05, 15.64, 5.0, 10.79, 0.2, 5.22, 15.57, 8.57, 10.85, 3.48, 21.98, 20.62, 20.69, 4.55, 8.29, 0.47, 18.13, 2.08, 9.48, 9.17, 3.3, 8.2, 15.19, 0.91, 2.01, 3.89, 7.47, 0.11, 8.85, 8.18, 30.31, 5.16, 4.11, 10.09, 9.81, 10.69, 4.71, 16.06, 1.71, 11.56, 19.12, 14.52, 15.03, 9.05, 16.49, 3.77, 5.63, 3.49, 4.84, 5.59, 4.49, 0.82, 11.34, 5.1, 12.18, 11.63, 7.59, 16.93, 4.83, 7.93, 7.48, 14.74, 21.35, 5.84, 1.57, 0.25, 1.42, 4.42, 7.16, 10.57, 13.06, 15.55, 2.87, 7.24, 4.63, 6.8, 2.08, 6.16, 8.7, 17.31, 6.83, 2.12, 16.35, 9.27, 15.72, 3.81, 6.46, 5.74, 21.81, 10.71, 11.9, 5.34, 22.45, 11.59, 16.28, 10.03, 20.11, 17.05, 17.43, 11.89, 1.08, 5.4, 23.96, 5.45, 18.66, 6.92, 5.78, 2.67, 25.59, 9.0, 5.63, 3.54, 1.88, 9.82, 14.05, 3.74, 2.9, 3.69, 6.24, 16.44, 12.97, 3.33, 7.97, 5.09, 7.34, 1 ...

# %% [markdown]
# There are clearly several outliers in the data. Most of the observations lie between 0 and 40 dollars, with the median at $6.8 dollars. It is extremely likely that the high outliers with amount values within the 1000-2000 range are outliers due to data entry errors (forgetting the decimal separator). Since there are only a few such cases, they will be removed from the dataset from analysis.

# %%
df[df['Amount']>50]
# Out:
#       TransactionID TransactionDate  CustomerID  Amount
# 23               24      2011-10-07           7  1003.0
# 211             212      2014-05-14          54  1027.0
# 4177           4178      2012-08-13        1000  2033.0

# %%
# remove outliers with negative amount values 
df = df[(df['Amount']<50) & (df['Amount']>0)].copy()

# %% [markdown]
# 5 total rows with outlier values are removed.

# %%
df.shape
# Out:
# (4181, 4)

# %% [markdown]
# To confirm that the rest of the data are good data, plot a histogram of the amount column. Clearly, this is a skewed distribution with a right tail.

# %%
fig = px.histogram(df, x="Amount")
fig.show()
# Out:
# <div>                            <div id="56c544c1-e1d6-4d61-ad8b-66bd92342305" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("56c544c1-e1d6-4d61-ad8b-66bd92342305")) {                    Plotly.newPlot(                        "56c544c1-e1d6-4d61-ad8b-66bd92342305",                        [{"alignmentgroup": "True", "bingroup": "x", "hovertemplate": "Amount=%{x}<br>count=%{y}<extra></extra>", "legendgroup": "", "marker": {"color": "#636efa"}, "name": "", "offsetgroup": "", "orientation": "v", "showlegend": false, "type": "histogram", "x": [20.26, 10.87, 2.21, 10.48, 3.94, 12.37, 1.59, 2.75, 3.51, 21.58, 15.43, 5.45, 1.67, 2.23, 9.92, 6.16, 0.54, 14.54, 6.9, 2.56, 17.02, 8.18, 9.44, 6.21, 2.35, 0.52, 6.58, 0.74, 11.87, 15.5, 11.46, 7.99, 2.97, 12.37, 5.99, 0.95, 8.81, 10.94, 20.21, 12.97, 4.78, 2.4, 13.91, 17.6, 0.5, 10.21, 5.1, 16.46, 9.67, 7.08, 14.45, 10.63, 37.27, 20.44, 7.84, 2.05, 0.36, 3.43, 4.78, 1.29, 28.72, 0.86, 9.22, 6.63, 1.85, 0.6, 2.69, 17.84, 6.0, 2.51, 8.34, 11.32, 10.8, 18.33, 6.01, 11.01, 15.04, 0.21, 18.05, 4.53, 6.24, 8.38, 3.67, 19.6, 4.55, 1.5, 0.49, 14.07, 10.33, 5.81, 15.92, 10.72, 9.36, 5.03, 2.26, 10.95, 0.19, 4.43, 2.47, 8.23, 7.73, 5.62, 6.98, 5.68, 13.45, 5.35, 14.47, 3.45, 3.9, 1.18, 2.81, 4.68, 7.66, 9.32, 0.96, 1.81, 9.93, 3.27, 0.52, 5.14, 3.95, 9.81, 10.26, 10.91, 12.28, 21.13, 2.78, 13.44, 1.77, 2.65, 12.03, 4.92, 1.91, 13.82, 25.6, 2.47, 5.02, 2.23, 12.3, 12.82, 2.74, 0.25, 9.72, 4.3, 2.45, 4.78, 11.75, 0.94, 8.21, 2.99, 0.04, 9.51, 12.7, 11.29, 4.83, 2.3, 5.52, 6.0, 7.18, 12.39, 17.82, 0.75, 3.47, 29.12, 8.49, 3.49, 11.57, 3.27, 9.8, 14.94, 4.97, 0.73, 3.69, 11.4, 22.53, 19.95, 11.39, 1.55, 11.12, 10.66, 2.61, 5.97, 24.05, 8.91, 9.77, 1.43, 5.9, 8.11, 8.19, 4.57, 12.2, 13.24, 8.23, 12.61, 5.28, 1.08, 10.12, 22.84, 10.19, 5.4, 10.49, 7.83, 7.85, 1.57, 0.96, 8.83, 1.92, 0.25, 13.85, 11.6, 15.1, 5.49, 0.9, 6.69, 7.21, 8.09, 11.61, 10.48, 1.64, 6.58, 10.76, 5.55, 9.96, 3.54, 3.35, 10.64, 2.64, 6.97, 5.81, 3.89, 8.67, 6.93, 3.54, 9.49, 9.6, 13.92, 12.23, 3.45, 5.86, 14.74, 13.46, 12.79, 13.33, 4.43, 7.21, 4.26, 7.49, 4.95, 3.47, 0.39, 1.35, 0.78, 1.25, 11.74, 14.2, 4.82, 0.45, 0.54, 3.4, 23.85, 38.29, 9.18, 4.4, 10.8, 0.37, 7.33, 23.95, 6.29, 11.83, 2.19, 11.66, 13.09, 2.43, 7.57, 0.58, 3.44, 17.72, 2.65, 7.73, 7.28, 4.49, 5.71, 4.48, 4.58, 8.43, 7.38, 9.06, 6.85, 14.21, 10.67, 9.45, 0.87, 1.22, 18.42, 14.44, 0.32, 9.08, 0.76, 20.58, 7.6, 9.41, 3.09, 11.88, 3.83, 5.01, 4.63, 11.55, 10.93, 1.5, 9.3, 1.82, 15.37, 6.61, 2.15, 2.26, 3.02, 2.18, 4.59, 3.64, 8.31, 10.43, 0.71, 2.79, 14.85, 14.05, 3.65, 3.46, 24.27, 17.48, 1.78, 3.95, 1.78, 8.99, 0.25, 21.01, 3.17, 14.72, 3.72, 2.63, 2.86, 2.84, 7.68, 3.59, 4.58, 1.19, 13.06, 3.13, 20.02, 7.78, 4.62, 0.2, 4.57, 13.4, 18.19, 2.64, 4.78, 11.29, 6.41, 5.53, 4.69, 17.4, 4.99, 12.51, 13.34, 7.28, 10.16, 17.93, 8.84, 13.46, 13.08, 10.89, 29.5, 7.67, 12.06, 20.04, 1.06, 0.59, 3.53, 6.33, 10.5, 3.74, 17.78, 16.45, 0.13, 8.1, 0.05, 15.64, 5.0, 10.79, 0.2, 5.22, 15.57, 8.57, 10.85, 3.48, 21.98, 20.62, 20.69, 4.55, 8.29, 0.47, 18.13, 2.08, 9.48, 9.17, 3.3, 8.2, 15.19, 0.91, 2.01, 3.89, 7.47, 0.11, 8.85, 8.18, 30.31, 5.16, 4.11, 10.09, 9.81, 10.69, 4.71, 16.06, 1.71, 11.56, 19.12, 14.52, 15.03, 9.05, 16.49, 3.77, 5.63, 3.49, 4.84, 5.59, 4.49, 0.82, 11.34, 5.1, 12.18, 11.63, 7.59, 16.93, 4.83, 7.93, 7.48, 14.74, 21.35, 5.84, 1.57, 0.25, 1.42, 4.42, 7.16, 10.57, 13.06, 15.55, 2.87, 7.24, 4.63, 6.8, 2.08, 6.16, 8.7, 17.31, 6.83, 2.12, 16.35, 9.27, 15.72, 3.81, 6.46, 5.74, 21.81, 10.71, 11.9, 5.34, 22.45, 11.59, 16.28, 10.03, 20.11, 17.05, 17.43, 11.89, 1.08, 5.4, 23.96, 5.45, 18.66, 6.92, 5.78, 2.67, 25.59, 9.0, 5.63, 3.54, 1.88, 9.82, 14.05, 3.74, 2.9, 3.69, 6.24, 16.44, 12.97, 3.33, 7.97, 5.09, 7.34, 12.59, 1.76, 1.32, 9.63, 1.62 ...

# %% [markdown]
# ##### Customer Cohort Assignment

# %% [markdown]
# First, create variable for the year of acquisition. This is based on the earliest transaction date that could be found for each customer.

# %%
# first get the earliest transaction date per customer 
acquisition_df = df.sort_values('TransactionDate').groupby('CustomerID').min().reset_index()

# %%
# next assign eac customer with his/her acquisition year 
acquisition_df['cohort'] = acquisition_df['TransactionDate'].dt.year.apply(lambda x: datetime.datetime(x,1, 1)).dt.date

# %%
acquisition_df
# Out:
#      CustomerID  TransactionID TransactionDate  Amount      cohort
# 0             1              1      2012-09-04   20.26  2012-01-01
# 1             2              2      2012-05-15    1.59  2012-01-01
# 2             3             10      2012-11-26    1.67  2012-01-01
# 3             4             17      2015-07-07    0.54  2015-01-01
# 4             5             18      2015-01-24    6.90  2015-01-01
# ..          ...            ...             ...     ...         ...
# 995         996           4152      2012-06-27    5.06  2012-01-01
# 996         997           4154      2014-10-14    7.93  2014-01-01
# 997         998           4156      2010-09-29    5.46  2010-01-01
# 998         999           4164      2011-04-18    0.80  2011-01-01
# 999        1000           4167      2010-03-03    0.83  2010-01-01
#
# [1000 rows x 5 columns]

# %%
# merge the cohort variable back into the original dataset
df = pd.merge(df, acquisition_df[['CustomerID', 'cohort']], how='left', on='CustomerID')

# %%
# spot check 
df[df['CustomerID']==2]
# Out:
#    TransactionID TransactionDate  CustomerID  Amount      cohort
# 1              2      2012-05-15           2   10.87  2012-01-01
# 2              3      2014-05-23           2    2.21  2012-01-01
# 3              4      2014-10-24           2   10.48  2012-01-01
# 4              5      2012-10-13           2    3.94  2012-01-01
# 5              6      2013-01-23           2   12.37  2012-01-01
# 6              7      2014-03-09           2    1.59  2012-01-01
# 7              8      2013-11-17           2    2.75  2012-01-01
# 8              9      2014-10-10           2    3.51  2012-01-01

# %% [markdown]
# ##### Calculate cumulative transactions

# %% [markdown]
# For cumulative transactions within a given age (e.g. 12 months), we need to find the transactions that occured within 12 months of the first date of the year of acquisition (e.g. 2010-01-01 - 2010-12-31). The first step is to calculate the difference in months between the transaction date and the cohort date.

# %%
df['timediff'] = ((df['TransactionDate'].dt.date - df['cohort'])/np.timedelta64(1, 'M')).apply(lambda x: math.ceil(x))

# %%
df.head()
# Out:
#    TransactionID TransactionDate  CustomerID  Amount      cohort  timediff
# 0              1      2012-09-04           1   20.26  2012-01-01         9
# 1              2      2012-05-15           2   10.87  2012-01-01         5
# 2              3      2014-05-23           2    2.21  2012-01-01        29
# 3              4      2014-10-24           2   10.48  2012-01-01        34
# 4              5      2012-10-13           2    3.94  2012-01-01        10

# %%
time_periods = [12, 24, 36, 48, 60, 72] 
cohorts = sorted(list(df['cohort'].unique()))
transactions = [] 
latest_transaction = df['TransactionDate'].max()

for c in cohorts:
    tr = []
    for t in time_periods:
        if c + relativedelta(months=+t-12) < latest_transaction:
            cumulative = df[(df['cohort']==c) & (df['timediff'] <= t)]['Amount'].sum().round(2)
            tr.append(cumulative)
        else:
            tr.append(None)
    transactions.append(tr)

# %%
df['Origin'] = df['cohort'].apply(lambda x: 
                                  (x.strftime('%Y-%m-%d') + 
                                  ' - ' + (x + relativedelta(days=364)).strftime('%Y-%m-%d')))

# %%
origin_list = sorted(list(df['Origin'].unique()))

# %%
cumulative_transactions = pd.DataFrame(transactions, columns = time_periods, index = origin_list)

# %%
cumulative_transactions.fillna('')
# Out:
#                             12       24       36       48       60       72
# 2010-01-01-2010-12-31  2262.13  3614.78  5274.81  6632.37  7930.69  8964.49
# 2011-01-01-2011-12-31  2252.70   3757.9  5465.99  6703.11  7862.24
# 2012-01-01-2012-12-30  2181.35  3874.69  5226.86  6501.85
# 2013-01-01-2013-12-31  2179.85  3609.81  5227.75
# 2014-01-01-2014-12-31  1830.85  3262.05
# 2015-01-01-2015-12-31  1912.17

# %% [markdown]
# ##### Calculate new customer count

# %%
customers = []

for c in cohorts:
    cs = []
    for t in time_periods:
        if c + relativedelta(months=+t-12) < latest_transaction:
            ct = len(df[df['cohort'] == c]['CustomerID'].unique())
            cs.append(ct)
        else:
            cs.append(None)
    customers.append(cs)

# %%
customer_counts = pd.DataFrame(customers, columns = time_periods, index = origin_list)

# %%
customer_counts.fillna('')
# Out:
#                         12   24   36   48   60   72
# 2010-01-01-2010-12-31  172  172  172  172  172  172
# 2011-01-01-2011-12-31  170  170  170  170  170
# 2012-01-01-2012-12-30  163  163  163  163
# 2013-01-01-2013-12-31  180  180  180
# 2014-01-01-2014-12-31  155  155
# 2015-01-01-2015-12-31  160

# %% [markdown]
# ##### Calculate historic CLV

# %%
historic_clv = cumulative_transactions.div(customer_counts).round(2)

# %%
historic_clv.fillna('')
# Out:
#                           12     24     36     48     60     72
# 2010-01-01-2010-12-31  13.15  21.02  30.67  38.56  46.11  52.12
# 2011-01-01-2011-12-31  13.25  22.11  32.15  39.43  46.25
# 2012-01-01-2012-12-30  13.38  23.77  32.07  39.89
# 2013-01-01-2013-12-31  12.11  20.05  29.04
# 2014-01-01-2014-12-31  11.81  21.05
# 2015-01-01-2015-12-31  11.95

# %%
fig = px.scatter(historic_clv.transpose(), labels={
     "value": "Historic CLV ($)",
     "index": "Age (months)",
     "variable": "Origin"
     }).update_traces(mode='lines+markers')

fig.update_layout(
    xaxis = dict(
        tickmode = 'array',
        tickvals = time_periods
    ),
    title = 'Historic CLV'
)

fig.show()
# Out:
# <div>                            <div id="f623b0a5-b262-4715-a9ba-6213a0675d73" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f623b0a5-b262-4715-a9ba-6213a0675d73")) {                    Plotly.newPlot(                        "f623b0a5-b262-4715-a9ba-6213a0675d73",                        [{"hovertemplate": "Origin=2010-01-01-2010-12-31<br>Age (months)=%{x}<br>Historic CLV ($)=%{y}<extra></extra>", "legendgroup": "2010-01-01-2010-12-31", "marker": {"color": "#636efa", "symbol": "circle"}, "mode": "lines+markers", "name": "2010-01-01-2010-12-31", "orientation": "v", "showlegend": true, "type": "scatter", "x": [12, 24, 36, 48, 60, 72], "xaxis": "x", "y": [13.15, 21.02, 30.67, 38.56, 46.11, 52.12], "yaxis": "y"}, {"hovertemplate": "Origin=2011-01-01-2011-12-31<br>Age (months)=%{x}<br>Historic CLV ($)=%{y}<extra></extra>", "legendgroup": "2011-01-01-2011-12-31", "marker": {"color": "#EF553B", "symbol": "circle"}, "mode": "lines+markers", "name": "2011-01-01-2011-12-31", "orientation": "v", "showlegend": true, "type": "scatter", "x": [12, 24, 36, 48, 60, 72], "xaxis": "x", "y": [13.25, 22.11, 32.15, 39.43, 46.25, null], "yaxis": "y"}, {"hovertemplate": "Origin=2012-01-01-2012-12-30<br>Age (months)=%{x}<br>Historic CLV ($)=%{y}<extra></extra>", "legendgroup": "2012-01-01-2012-12-30", "marker": {"color": "#00cc96", "symbol": "circle"}, "mode": "lines+markers", "name": "2012-01-01-2012-12-30", "orientation": "v", "showlegend": true, "type": "scatter", "x": [12, 24, 36, 48, 60, 72], "xaxis": "x", "y": [13.38, 23.77, 32.07, 39.89, null, null], "yaxis": "y"}, {"hovertemplate": "Origin=2013-01-01-2013-12-31<br>Age (months)=%{x}<br>Historic CLV ($)=%{y}<extra></extra>", "legendgroup": "2013-01-01-2013-12-31", "marker": {"color": "#ab63fa", "symbol": "circle"}, "mode": "lines+markers", "name": "2013-01-01-2013-12-31", "orientation": "v", "showlegend": true, "type": "scatter", "x": [12, 24, 36, 48, 60, 72], "xaxis": "x", "y": [12.11, 20.05, 29.04, null, null, null], "yaxis": "y"}, {"hovertemplate": "Origin=2014-01-01-2014-12-31<br>Age (months)=%{x}<br>Historic CLV ($)=%{y}<extra></extra>", "legendgroup": "2014-01-01-2014-12-31", "marker": {"color": "#FFA15A", "symbol": "circle"}, "mode": "lines+markers", "name": "2014-01-01-2014-12-31", "orientation": "v", "showlegend": true, "type": "scatter", "x": [12, 24, 36, 48, 60, 72], "xaxis": "x", "y": [11.81, 21.05, null, null, null, null], "yaxis": "y"}, {"hovertemplate": "Origin=2015-01-01-2015-12-31<br>Age (months)=%{x}<br>Historic CLV ($)=%{y}<extra></extra>", "legendgroup": "2015-01-01-2015-12-31", "marker": {"color": "#19d3f3", "symbol": "circle"}, "mode": "lines+markers", "name": "2015-01-01-2015-12-31", "orientation": "v", "showlegend": true, "type": "scatter", "x": [12, 24, 36, 48, 60, 72], "xaxis": "x", "y": [11.95, null, null, null, null, null], "yaxis": "y"}],                        {"legend": {"title": {"text": "Origin"}, "tracegroupgap": 0}, "margin": {"t": 60}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, " ...

# %% [markdown]
# Next, calculate the single combined curve of Historic CLV by taking the weighted average of the historic CLV at each Age.

# %%
combined_clv =pd.DataFrame((historic_clv * customer_counts).sum().div(customer_counts.sum()).round(2), columns = ['HistoricCLV']).reset_index().rename(columns = {'index' : 'Age'})

# %%
combined_clv
# Out:
#    Age  HistoricCLV
# 0   12        12.62
# 1   24        21.57
# 2   36        30.94
# 3   48        39.28
# 4   60        46.18
# 5   72        52.12

# %% [markdown]
# ##### Interpretation

# %% [markdown]
# Customers acquired in 2011 have spent $7,862.24 to date.

# %%
cumulative_transactions.loc['2011-01-01-2011-12-31'].max()
# Out:
# 7862.24

# %% [markdown]
# Based on the visualization above, each cohort (ie. origin) group typically increases their cumulative spending (and therefore their historic CLV) in a similar upward trajectory (i.e. the slopes of the lines are relatively similar). However, when comparing the historic CLV between groups at different age cutoffs, it is clear that customers acquired in 2013 generally have higher CLV than customers acquired other years. This is a cohort of high value customers and retention efforts should focus on this group, as they represent higher CLV for the business.
#
# Customers acquired in 2013 seems to have lower historic CLV compared to other cohorts. This is alarming for the business, and indicate that additional marketing efforts should be targeted towards this cohort in order to increase their CLV. Additionally, at the 12 month mark, customers in the later cohorts (2013-2015) have lower CLV compared to earlier customer cohorts, suggesting that additional marketing at the onset of customer acquistion should be incorporated in order to increase the amount of cumulative transactions per customers during the first 12 months of their customer history.
